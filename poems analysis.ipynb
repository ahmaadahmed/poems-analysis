# %%
import pandas as pd

# %%
# Specify the path to your CSV file
csv_file_path = r'E:\New folder\Arabic PCD\Arabic Poem Comprehensive Dataset (APCD).csv'

# Read the TSV file into a Pandas DataFrame
ar_tweets = pd.read_csv(csv_file_path)

# %%
ar_tweets
# Out:
#                العصر             الشاعر          الديوان القافية   البحر  \
# 0        قبل الإسلام  عمرو بنِ قُمَيئَة  الديوان الرئيسي       د  الطويل
# 1        قبل الإسلام  عمرو بنِ قُمَيئَة  الديوان الرئيسي       د  الطويل
# 2        قبل الإسلام  عمرو بنِ قُمَيئَة  الديوان الرئيسي       د  الطويل
# 3        قبل الإسلام  عمرو بنِ قُمَيئَة  الديوان الرئيسي       د  الطويل
# 4        قبل الإسلام  عمرو بنِ قُمَيئَة  الديوان الرئيسي       د  الطويل
# ...              ...                ...              ...     ...     ...
# 1831765       الحديث          شهاب غانم        شهاب غانم       ن  الخفيف
# 1831766       الحديث          شهاب غانم        شهاب غانم       ن  الخفيف
# 1831767       الحديث          شهاب غانم        شهاب غانم       ن  الخفيف
# 1831768       الحديث          شهاب غانم        شهاب غانم       ن  الخفيف
# 1831769       الحديث          شهاب غانم        شهاب غانم       ن  الخفيف
#
#                                   الشطر الايسر  \
# ...

# %%
# Set the display option to show 100 rows
pd.set_option("display.max_rows", 100)

# %%
ar_tweets["الشاعر"].value_counts()
# Out:
# الشاعر
# ابن الرومي             30469
# مهيار الديلمي          22457
# خليل مطران             20719
# أحمد شوقي              16208
# الشريف الرضي           16199
#                        ...
# رَذاذُ الكلبي              1
# أبو دُؤَاد الكَلبي         1
# ابن الحارث الهمداني        1
# حابِس بن دِرْهم            1
# الشعباني                   1
# Name: count, Length: 3569, dtype: int64

# %%
ar_tweets["الشاعر"].value_counts().head(100)
# Out:
# الشاعر
# ابن الرومي                   30469
# مهيار الديلمي                22457
# خليل مطران                   20719
# أحمد شوقي                    16208
# الشريف الرضي                 16199
# البُحتُرِيّ                  15850
# جميل صدقي الزهاوي            14754
# أحمد محرم                    14743
# عبد الغني النابلسي           13957
# الشريف المرتضى               13782
# أَبو العَلاء المَعَرِي       13621
# ابن نباتة المصري             13355
# حسن حسني الطويراني           13263
# ناصح الدين الأرجاني          12764
# المفتي فتح الله              12180
# الأخرس                       11696
# محيي الدين بن عربي           10210
# ابن المقري                    9562
# أحمد الكاشف                   9322
# صَفِيِّ الدينِ الحِلِّي       9254
# الحيص بيص                     9134
# صالح مجدي                     9046
# شهاب الدين الخلوف             8827
# أبو نُوّاس                    8796
# شرف الدين الحلي               8778
# أبو الهدى الصيادي             8742
# ...

# %%
ar_tweets[ar_tweets["الشاعر"]=="المُتَنَبّي"]
# Out:
#         العصر       الشاعر          الديوان القافية   البحر  \
# 396   العباسي  المُتَنَبّي  الديوان الرئيسي       ء  الكامل
# 397   العباسي  المُتَنَبّي  الديوان الرئيسي       ء  الكامل
# 398   العباسي  المُتَنَبّي  الديوان الرئيسي       ء  الكامل
# 399   العباسي  المُتَنَبّي  الديوان الرئيسي       ء  الكامل
# 400   العباسي  المُتَنَبّي  الديوان الرئيسي       ء  الكامل
# ...       ...          ...              ...     ...     ...
# 5968  العباسي  المُتَنَبّي  الديوان الرئيسي       ي  الكامل
# 5969  العباسي  المُتَنَبّي  الديوان الرئيسي       ي  الكامل
# 5970  العباسي  المُتَنَبّي  الديوان الرئيسي       ي  الكامل
# 5971  العباسي  المُتَنَبّي  الديوان الرئيسي       م  الطويل
# 5972  العباسي  المُتَنَبّي  الديوان الرئيسي       م  الطويل
#
#                               الشطر الايسر  \
# 396   وَأَحَقُّ مِنكَ بِجَفنِهِ وَبِمائِهِ
# 397    قَسَماً بِهِ وَبِحُسنِهِ وَبَهائِهِ
# 398    إِنَّ المَلامَةَ فيهِ مِن أَعدائِهِ
# 399    دَع ما بَراكَ ضَعُفتَ عَن إِخفائِهِ
# ...

# %%
ar_tweets["القافية"].value_counts()
# Out:
# القافية
# ر     286498
# ل     212798
# م     204675
# د     203339
# ب     177086
# ن     173349
# ع      72427
# ق      70024
# ء      53387
# ت      53347
# ف      45571
# ح      44332
# ه      41384
# س      37657
# ي      33326
# ك      28854
# ج      16647
# ض      12913
# ا       8943
# ط       8291
# ز       5495
# ش       5408
# و       5138
# ص       5078
# ث       4201
# ذ       2845
# خ       2434
# غ       2190
# ظ       1705
# ى       1358
# -       1007
# هـ       200
# ة         80
# ؤ          8
# هن         6
# طن         6
# لا         3
# Name: count, dtype: int64

# %%
top_values = ar_tweets['القافية'].value_counts().head(1).index

# %%
ar_tweets[(ar_tweets['الشاعر'] == 'المُتَنَبّي') & ar_tweets['القافية'].isin(top_values)]
# Out:
#         العصر       الشاعر          الديوان القافية     البحر  \
# 2062  العباسي  المُتَنَبّي  الديوان الرئيسي       ر    الكامل
# 2063  العباسي  المُتَنَبّي  الديوان الرئيسي       ر    الكامل
# 2064  العباسي  المُتَنَبّي  الديوان الرئيسي       ر    الكامل
# 2065  العباسي  المُتَنَبّي  الديوان الرئيسي       ر    الكامل
# 2066  العباسي  المُتَنَبّي  الديوان الرئيسي       ر    الكامل
# 2067  العباسي  المُتَنَبّي  الديوان الرئيسي       ر    الكامل
# 2068  العباسي  المُتَنَبّي  الديوان الرئيسي       ر    الكامل
# 2069  العباسي  المُتَنَبّي  الديوان الرئيسي       ر    الكامل
# 2070  العباسي  المُتَنَبّي  الديوان الرئيسي       ر    الكامل
# 2071  العباسي  المُتَنَبّي  الديوان الرئيسي       ر    الكامل
# 2072  العباسي  المُتَنَبّي  الديوان الرئيسي       ر    الكامل
# 2073  العباسي  المُتَنَبّي  الديوان الرئيسي       ر    الكامل
# 2074  العباسي  المُتَنَبّي  الديوان الرئيسي       ر    الكامل
# 2075  العباسي  المُتَنَبّي  الديوان الرئيسي       ر    الكامل
# ...

# %%
# Filter rows where 'الشاعر' is 'المُتَنَبّي'
mutanabbi_rows = ar_tweets[ar_tweets['الشاعر'] == 'المُتَنَبّي']

# Get the value counts for 'القافية' types for 'المُتَنَبّي'
qafiya_counts = mutanabbi_rows['القافية'].value_counts()

# %%
qafiya_counts
# Out:
# القافية
# ل    1165
# م     907
# د     747
# ب     691
# ر     416
# ن     378
# ق     301
# ع     224
# ء     151
# ك      90
# ه      77
# س      67
# ف      65
# ح      65
# ي      61
# ت      50
# ز      38
# ش      36
# ذ      17
# ج      15
# ض       9
# ط       7
# Name: count, dtype: int64
